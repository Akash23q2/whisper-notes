# %%
from app.services.rag_service import data_injestion, query_engine, delete_data
# import markdown
def main():
    print("Hello from whisper-notes!")
    rag_model=data_injestion(pdf_url='https://unacademy.com/content/wp-content/uploads/sites/2/2022/10/4.-Chemical-bonding-Notes-min.pdf')
    query=1
    while query:
        query=input("Enter your query: ")
        results=query_engine(rag_model,query=query,n_results=10)
        print(results)


if __name__ == "__main__":
    main()
# Out:
# Hello from whisper-notes!
# Data Ingestion completed. Total 211 chunks created.
# ...
